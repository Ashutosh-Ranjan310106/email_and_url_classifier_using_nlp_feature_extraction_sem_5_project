# %%
import torch

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 model = torch.load(r"training_runs\2025-11-23_11-36-46_final_model_on_dataset_Dataset 1 (Malicious URLs)\best_loss_model.pt")
# ----> 2 model.eval()
#
# AttributeError: 'collections.OrderedDict' object has no attribute 'eval'
