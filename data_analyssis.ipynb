# %%
from tqdm import tqdm
import numpy as np



import random
tqdm.pandas()
seed = 42
random.seed(seed)
np.random.seed(seed)


print(f"✅ Seed fixed to {seed}")

# %%
import matplotlib.pyplot as plt
import pandas as pd
from preprocess_datasets import all_dataset
def draw_boxplots_for_dataset(name, splits):
    fig, axs = plt.subplots(1, 3, figsize=(18, 5))
    fig.suptitle(f"URL Length Boxplots for Dataset: {name}", fontsize=14)

    for ax, (split_name, df) in zip(axs, zip(["train", "valid", "test"], splits)):

        # URL length
        df["url_len"] = df["url"].astype(str).apply(len)

        # Data groups
        overall = df["url_len"]
        safe = df[df["label"] == 0]["url_len"]
        phishing = df[df["label"] == 1]["url_len"]

        # Boxplot
        ax.boxplot(
            [overall, safe, phishing],
            labels=["Overall", "Safe", "Phishing"],
            showmeans=True
        )

        ax.set_title(f"{split_name.upper()} ({len(df)} URLs)")
        ax.set_ylabel("URL Length")
        ax.grid(True, axis='y', linestyle='--', alpha=0.5)

    plt.tight_layout()
    plt.show()



gen = all_dataset()

for name, splits in gen:
    print(f"\n==============================")
    print(f"DATASET: {name}")
    print("==============================")

    # Print info + ratios
    for split_name, df in zip(['train', 'valid', 'test'], splits):

        print(f"\n--- {split_name.upper()} ---")
        print(f"Total URLs: {len(df)}")

        safe = (df["label"] == 0).sum()
        phish = (df["label"] == 1).sum()

        print(f"Safe (0): {safe}")
        print(f"Phishing (1): {phish}")
        print(f"Ratio: {safe}:{phish}")

    # Draw 3-subplot figure
    draw_boxplots_for_dataset(name, splits)
# Out:
# ==============================
# DATASET: Dataset 1 (Malicious URLs)
# ==============================
#
# --- TRAIN ---
# Total URLs: 417732
# Safe (0): 342463
# Phishing (1): 75269
# Ratio: 342463:75269
#
# --- VALID ---
# Total URLs: 52217
# Safe (0): 42809
# Phishing (1): 9408
# Ratio: 42809:9408
#
# --- TEST ---
# Total URLs: 52217
# Safe (0): 42808
# Phishing (1): 9409
# Ratio: 42808:9409
# C:\Users\rrpra\AppData\Local\Temp\ipykernel_13024\230425360.py:19: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(
# C:\Users\rrpra\AppData\Local\Temp\ipykernel_13024\230425360.py:19: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(
# C:\Users\rrpra\AppData\Local\Temp\ipykernel_13024\230425360.py:19: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(
# ==============================
# DATASET: Dataset 2 (ndarvind/phiusiil-phishing)
# ==============================
#
# --- TRAIN ---
# Total URLs: 188296
# Safe (0): 80416
# Phishing (1): 107880
# Ratio: 80416:107880
#
# --- VALID ---
# Total URLs: 23537
# Safe (0): 10052
# Phishing (1): 13485
# Ratio: 10052:13485
#
# --- TEST ---
# Total URLs: 23537
# Safe (0): 10052
# Phishing (1): 13485
# Ratio: 10052:13485
# C:\Users\rrpra\AppData\Local\Temp\ipykernel_13024\230425360.py:19: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(
# C:\Users\rrpra\AppData\Local\Temp\ipykernel_13024\230425360.py:19: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(
# C:\Users\rrpra\AppData\Local\Temp\ipykernel_13024\230425360.py:19: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(
# ==============================
# DATASET: Dataset 3 (kmack/Phishing_urls)
# ==============================
#
# --- TRAIN ---
# Total URLs: 528097
# Safe (0): 264169
# Phishing (1): 263928
# Ratio: 264169:263928
#
# --- VALID ---
# Total URLs: 66013
# Safe (0): 33022
# Phishing (1): 32991
# Ratio: 33022:32991
#
# --- TEST ---
# Total URLs: 66012
# Safe (0): 33021
# Phishing (1): 32991
# Ratio: 33021:32991
# C:\Users\rrpra\AppData\Local\Temp\ipykernel_13024\230425360.py:19: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(
# C:\Users\rrpra\AppData\Local\Temp\ipykernel_13024\230425360.py:19: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(
# C:\Users\rrpra\AppData\Local\Temp\ipykernel_13024\230425360.py:19: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(
# ==============================
# DATASET: Dataset 4 (kaggels/taruntiwarihp/phishing-site-urls)
# ==============================
#
# --- TRAIN ---
# Total URLs: 405756
# Safe (0): 314318
# Phishing (1): 91438
# Ratio: 314318:91438
#
# --- VALID ---
# Total URLs: 50720
# Safe (0): 39290
# Phishing (1): 11430
# Ratio: 39290:11430
#
# --- TEST ---
# Total URLs: 50719
# Safe (0): 39289
# Phishing (1): 11430
# Ratio: 39289:11430
# C:\Users\rrpra\AppData\Local\Temp\ipykernel_13024\230425360.py:19: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(
# C:\Users\rrpra\AppData\Local\Temp\ipykernel_13024\230425360.py:19: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(
# C:\Users\rrpra\AppData\Local\Temp\ipykernel_13024\230425360.py:19: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(
# ==============================
# DATASET: Dataset 5 (grambeddings)
# ==============================
#
# --- TRAIN ---
# Total URLs: 639999
# Safe (0): 319999
# Phishing (1): 320000
# Ratio: 319999:320000
#
# --- VALID ---
# Total URLs: 80000
# Safe (0): 40000
# Phishing (1): 40000
# Ratio: 40000:40000
#
# --- TEST ---
# Total URLs: 80000
# Safe (0): 40000
# Phishing (1): 40000
# Ratio: 40000:40000
# C:\Users\rrpra\AppData\Local\Temp\ipykernel_13024\230425360.py:19: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(
# C:\Users\rrpra\AppData\Local\Temp\ipykernel_13024\230425360.py:19: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(
# C:\Users\rrpra\AppData\Local\Temp\ipykernel_13024\230425360.py:19: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(
