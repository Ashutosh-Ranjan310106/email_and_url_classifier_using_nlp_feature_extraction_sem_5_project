# %%
import pandas as pd

# Load JSON file into DataFrame
df = pd.read_json(r"C:\Users\LENOVO\Downloads\8339691.json")

# View
print(df.head())

# Save as CSV
df.to_csv('output.csv', index=False)
# Out:
#                                        access  \
# embargo     {'active': False, 'reason': None}
# files                                  public
# record                                 public
# status                                   open
# is_deleted                                NaN
#
#                                      created  custom_fields deletion_status  \
# embargo     2023-09-13T04:14:04.561436+00:00            NaN             NaN
# files       2023-09-13T04:14:04.561436+00:00            NaN             NaN
# record      2023-09-13T04:14:04.561436+00:00            NaN             NaN
# status      2023-09-13T04:14:04.561436+00:00            NaN               P
# is_deleted  2023-09-13T04:14:04.561436+00:00            NaN           False
#
#            files       id  is_draft  is_published  \
# embargo      NaN  8339691     False          True
# files        NaN  8339691     False          True
# record       NaN  8339691     False          True
# ...

# %%
df
# Out:
#                                                     access  \
# embargo                  {'active': False, 'reason': None}
# files                                               public
# record                                              public
# status                                                open
# is_deleted                                             NaN
# count                                                  NaN
# enabled                                                NaN
# entries                                                NaN
# order                                                  NaN
# total_bytes                                            NaN
# access                                                 NaN
# access_grants                                          NaN
# access_links                                           NaN
# access_request                                         NaN
# access_users                                           NaN
# ...
